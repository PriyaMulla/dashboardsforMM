# %%
import matplotlib.pyplot as plt 
import numpy as np
from PIL import Image
from scipy.ndimage import maximum_filter

# %%
img = np.asarray(Image.open(r"C:\Users\lociu\Desktop\PriyaM\20230522_sample_minmax\priya_samplefile.tif"))
plt.imshow(img)

# %%
mx = img*(img == maximum_filter(img, footprint=np.ones((3,3))))
plt.imshow(mx)

index = np.where(mx!= 0)
coord = list(zip(index[0], index[1]))
print(coord)
# Out:
# [(0, 25), (0, 60), (1, 42), (2, 6), (2, 24), (3, 41), (9, 72), (22, 5), (23, 40), (24, 58), (25, 21), (27, 72), (32, 13), (36, 7), (36, 25), (36, 43), (36, 61), (36, 72)]
